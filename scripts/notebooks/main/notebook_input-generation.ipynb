# %%
# Create templates for VHHs
import tqdm
import os

import protein_benchmark.data_utility as du
import protein_benchmark.samples.epitope_specification as e

original_pdbs = "/home/cp864/repos/incito-pipeline/incito_pipeline/datasets/AF3_independent_test_Fv_GroundTruth"

path_to_templates = "/spinning1/home/cp864/boltz_2_new/19_08_2025/dataset/seperated_pdbs/fv"
yaml_output_path = "/spinning1/home/cp864/boltz_2_new/19_08_2025/yaml/v2/pocket%/100%/fv"

dirs = du.get_dirs(path_to_templates)

for dir in dirs:
    dir_name = os.path.basename(dir).split('boltz_results_')[-1]

    ab_path = str(os.path.join(path_to_templates, dir, "ab.pdb"))
    ag_path = str(os.path.join(path_to_templates, dir, "ag.pdb"))

    path_to_original_pdb = os.path.join(original_pdbs, f"{dir_name}.pdb")


    # Loose Epitope Specification, with antigen and antibody templates
    e.create_yaml_with_retrieved_epitopes(pdb_file=path_to_original_pdb,
                                          save_dir=yaml_output_path,
                                          chain_map={"H": "H", "L":"L", "A": "A"},
                                          epitope_cutoff=4.5,
                                          msa=None,

                                          enforce_templates=True,
                                          template_constraint_threshold=0.01,
                                          template_paths=[ag_path, ab_path],
                                          chain_ids=[["A"], ["H", "L"]],
                                          template_ids=[["A1"], ["H1", "L1"]],

                                          enforce_pocket=True,
                                          pocket_constraint_threshold=1,
                                          pocket_percentage=1,

                                          chain_filter_native=["H", "L"],
                                          chain_filter_model=["A"],
                                          )
    """
    # Loose Epitope Specification
    e.create_yaml_with_retrieved_epitopes(pdb_file=path_to_original_pdb,
                                          save_dir=yaml_output_path,
                                          chain_map={"H": "H", "L":"L", "A": "A"},
                                          epitope_cutoff=4.5,
                                          msa=None,

                                          enforce_pocket=True,
                                          pocket_constraint_threshold=1,
                                          pocket_percentage=1,

                                          chain_filter_native=["H", "L"],
                                          chain_filter_model=["A"],
                                          )
    """
    """
    # Restricted Epitope Specification
    e.create_yaml_with_retrieved_epitopes(pdb_file=path_to_original_pdb,
                                          save_dir=yaml_output_path,
                                          chain_map={"H": "H", "L":"L", "A": "A"},
                                          epitope_cutoff=4.5,
                                          msa=None,

                                          enforce_pocket=True,
                                          pocket_constraint_threshold=0.01,
                                          pocket_percentage=1,

                                          chain_filter_native=["H", "L"],
                                          chain_filter_model=["A"],
                                          )
    """
    """
    # Baseline Epitope Specification
    e.create_yaml_with_retrieved_epitopes(pdb_file=path_to_original_pdb,
                                          save_dir=yaml_output_path,
                                          chain_map={"H": "H", "L":"L", "A": "A"},
                                          epitope_cutoff=4.5,
                                          msa=None,

                                          chain_filter_native=["H", "L"],
                                          chain_filter_model=["A"],
                                          )
    """
    """
    # Restricted Template constraints - Ab, Ag templates
    e.create_yaml_with_retrieved_epitopes(pdb_file=path_to_original_pdb,
                                          save_dir=yaml_output_path,
                                          chain_map={"H": "H", "L":"L", "A": "A"},
                                          epitope_cutoff=4.5,
                                          msa=None,

                                          enforce_templates=True,
                                          template_constraint_threshold=0.01,
                                          template_paths=[ag_path, ab_path],
                                          chain_ids=[["A"], ["H", "L"]],
                                          template_ids=[["A1"], ["H1", "L1"]],

                                          chain_filter_native=["H", "L"],
                                          chain_filter_model=["A"],
                                          )
    """
    """
    # Restricted Template constraints - Ag templates
    e.create_yaml_with_retrieved_epitopes(pdb_file=path_to_original_pdb,
                                          save_dir=yaml_output_path,
                                          chain_map={"H": "H", "L":"L", "A": "A"},
                                          epitope_cutoff=4.5,
                                          msa=None,

                                          enforce_templates=True,
                                          template_constraint_threshold=0.01,
                                          template_paths=[ag_path],
                                          chain_ids=[["A"]],
                                          template_ids=[["A1"]],

                                          chain_filter_native=["H", "L"],
                                          chain_filter_model=["A"],
                                          )
    """
    """
    # Restricted Template constraints - Ab templates
    e.create_yaml_with_retrieved_epitopes(pdb_file=path_to_original_pdb,
                                          save_dir=yaml_output_path,
                                          chain_map={"H": "H", "L":"L", "A": "A"},
                                          epitope_cutoff=4.5,
                                          msa=None,

                                          enforce_templates=True,
                                          template_constraint_threshold=0.01,
                                          template_paths=[ab_path],
                                          chain_ids=[["H", "L"]],
                                          template_ids=[["H1", "L1"]],

                                          chain_filter_native=["H", "L"],
                                          chain_filter_model=["A"],
                                          )
    """
    """
    # Loose Template constraints - Ab, Ag templates
    e.create_yaml_with_retrieved_epitopes(pdb_file=path_to_original_pdb,
                                          save_dir=yaml_output_path,
                                          chain_map={"H": "H", "L":"L", "A": "A"},
                                          epitope_cutoff=4.5,
                                          msa=None,

                                          enforce_templates=True,
                                          template_constraint_threshold=1,
                                          template_paths=[ag_path, ab_path],
                                          chain_ids=[["A"], ["H", "L"]],
                                          template_ids=[["A1"], ["H1", "L1"]],

                                          chain_filter_native=["H", "L"],
                                          chain_filter_model=["A"],
                                          )
    """
    """
    # Loose Template constraints - Ag templates
    e.create_yaml_with_retrieved_epitopes(pdb_file=path_to_original_pdb,
                                          save_dir=yaml_output_path,
                                          chain_map={"H": "H", "L":"L", "A": "A"},
                                          epitope_cutoff=4.5,
                                          msa=None,

                                          enforce_templates=True,
                                          template_constraint_threshold=1,
                                          template_paths=[ag_path],
                                          chain_ids=[["A"]],
                                          template_ids=[["A1"]],

                                          chain_filter_native=["H", "L"],
                                          chain_filter_model=["A"],
                                          )
    """
    """
    # Loose Template constraints - Ab templates
    e.create_yaml_with_retrieved_epitopes(pdb_file=path_to_original_pdb,
                                          save_dir=yaml_output_path,
                                          chain_map={"H": "H", "L":"L", "A": "A"},
                                          epitope_cutoff=4.5,
                                          msa=None,

                                          enforce_templates=True,
                                          template_constraint_threshold=1,
                                          template_paths=[ab_path],
                                          chain_ids=[["H", "L"]],
                                          template_ids=[["H1", "L1"]],

                                          chain_filter_native=["H", "L"],
                                          chain_filter_model=["A"],
                                          )
    """
# Out:
# Error: File path does not exist: /spinning1/home/cp864/boltz_2_new/19_08_2025/dataset/seperated_pdbs/fv

# %%
# Create templates for VHHs
import tqdm
import os

import protein_benchmark.data_utility as du
import protein_benchmark.samples.epitope_specification as e

original_pdbs = "/home/cp864/repos/incito-pipeline/incito_pipeline/datasets/AF3_independent_test_VHHs_GroundTruth"

path_to_templates = "/spinning1/home/cp864/boltz_2_new/19_08_2025/dataset/seperated_pdbs/vhh"
yaml_output_path = "/spinning1/home/cp864/boltz_2_new/19_08_2025/yaml/v2/template_chainmap_ab/vhh"

dirs = du.get_dirs(path_to_templates)

for dir in dirs:
    dir_name = os.path.basename(dir).split('boltz_results_')[-1]

    ab_path = str(os.path.join(path_to_templates, dir, "ab.pdb"))
    ag_path = str(os.path.join(path_to_templates, dir, "ag.pdb"))

    path_to_original_pdb = os.path.join(original_pdbs, f"{dir_name}.pdb")

    e.create_yaml_with_retrieved_epitopes(pdb_file=path_to_original_pdb,
                                          save_dir=yaml_output_path,
                                          chain_map={"H": "H", "L":"L", "A": "A"},
                                          epitope_cutoff=4.5,
                                          msa=None,

                                          enforce_templates=True,
                                          template_constraint_threshold=0.01,
                                          template_paths=[ab_path],
                                          chain_ids=[["H"]],
                                          template_ids=[["H1"]],

                                          enforce_pocket=True,
                                          pocket_constraint_threshold=1,
                                          pocket_percentage=1,

                                          chain_filter_native=["H", "L"],
                                          chain_filter_model=["A"],
                                          )
# Out:
# Error: File path does not exist: /spinning1/home/cp864/boltz_2_new/19_08_2025/dataset/seperated_pdbs/vhh
